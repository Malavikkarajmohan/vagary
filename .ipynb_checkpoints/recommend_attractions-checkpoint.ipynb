# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from collections import Counter
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Collecting scikit-learn (from sklearn)
#   Downloading https://files.pythonhosted.org/packages/d1/48/e9fa9e252abcd1447eff6f9257636af31758a6e46fd5ce5d3c879f6907cb/scikit_learn-0.22.1-cp36-cp36m-manylinux1_x86_64.whl (7.0MB)
#     100% |████████████████████████████████| 7.1MB 177kB/s ta 0:00:01
# Collecting scipy>=0.17.0 (from scikit-learn->sklearn)
#   Downloading https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1MB)
#     100% |████████████████████████████████| 26.1MB 63kB/s eta 0:00:011
# Collecting numpy>=1.11.0 (from scikit-learn->sklearn)
#   Using cached https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting joblib>=0.11 (from scikit-learn->sklearn)
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
#     100% |████████████████████████████████| 296kB 742kB/s ta 0:00:01
# Building wheels for collected packages: sklearn
#   Running setup.py bdist_wheel for sklearn ... done
#   Stored in directory: /home/shaanzie/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: numpy, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-0.14.1 numpy-1.18.1 scikit-learn-0.22.1 scipy-1.4.1 sklearn-0.0

# %%
amsterdam = pd.read_csv('datasets/amsterdam-attraction.csv')

amsterdam.head()
X=df.loc[:,['latitude','longitude']]
# Out:
#    Unnamed: 0               address     id        lat       lng   location  \
# 0           1        Diemerparklaan  28331  52.352237  4.987965  Amsterdam
# 1           6     krijn taconiskade  28336  52.353174  5.004712  Amsterdam
# 2          11          Talbotstraat  28341  52.357249  4.995746  Amsterdam
# 3          13  Emmy Andriessestraat  28344  52.350179  5.005388  Amsterdam
# 4          16       IJburg buitenom  28347  52.355692  4.994743  Amsterdam
#
#                      name         subCategory  \
# 0              Diemerpark                Park
# 1       Jachthaven ijburg           Surf Spot
# 2  Speeltuin Talbotstraat          Playground
# 3       Theo van Goghpark                Park
# 4           Rondje IJburg  Athletics & Sports
#
#                                              details
# 0  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 1  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 2  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 3  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 4  http://tour-pedia.org/api/getPlaceDetails?id=2...

# %%
#run KMeans
id_n=8
kmeans = KMeans(n_clusters=id_n, random_state=0).fit(X)
id_label=kmeans.labels_
